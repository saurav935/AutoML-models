# %%
# !pip install autoviml
# !pip install shap
# Out:
# Collecting autoviml
#   Downloading autoviml-0.1.683-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=0.23.1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (0.24.1)
# Requirement already satisfied: beautifulsoup4 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (4.9.3)
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 11.6 MB/s eta 0:00:01
# Requirement already satisfied: jupyter in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (1.0.0)
# Collecting emoji
#   Downloading emoji-1.6.1.tar.gz (170 kB)
#      |████████████████████████████████| 170 kB 17.8 MB/s eta 0:00:01
# Collecting shap>=0.36.0
#   Downloading shap-0.40.0.tar.gz (371 kB)
#      |████████████████████████████████| 371 kB 21.1 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: regex in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (2021.4.4)
# Collecting imbalanced-learn>=0.7
#   Downloading imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 17.5 MB/s eta 0:00:01
# Requirement already satisfied: ipython in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (7.22.0)
# Collecting catboost
#   Downloading catboost-1.0.0-cp38-none-manylinux1_x86_64.whl (76.4 MB)
#      |████████████████████████████████| 76.4 MB 15.6 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /home/oem/.local/lib/python3.8/site-packages (from autoviml) (1.3.4)
# Requirement already satisfied: nltk in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (3.6.1)
# Requirement already satisfied: seaborn in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (0.11.1)
# Requirement already satisfied: matplotlib in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (3.3.4)
# Collecting xgboost>=1.1.1
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#      |████████████████████████████████| 173.5 MB 13.2 MB/s eta 0:00:01
# Requirement already satisfied: xlrd in /home/oem/Downloads/yes/lib/python3.8/site-packages (from autoviml) (2.0.1)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 24.4 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.19.1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from imbalanced-learn>=0.7->autoviml) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from imbalanced-learn>=0.7->autoviml) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/oem/.local/lib/python3.8/site-packages (from imbalanced-learn>=0.7->autoviml) (1.21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from scikit-learn>=0.23.1->autoviml) (2.1.0)
# Requirement already satisfied: cloudpickle in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap>=0.36.0->autoviml) (1.6.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting packaging>20.9
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 7.0 MB/s  eta 0:00:01
# Requirement already satisfied: tqdm>4.25.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap>=0.36.0->autoviml) (4.59.0)
# Requirement already satisfied: numba in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap>=0.36.0->autoviml) (0.53.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from packaging>20.9->shap>=0.36.0->autoviml) (2.4.7)
# Requirement already satisfied: soupsieve>1.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from beautifulsoup4->autoviml) (2.2.1)
# Collecting graphviz
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Collecting plotly
#   Downloading plotly-5.3.1-py2.py3-none-any.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 16.3 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/oem/Downloads/yes/lib/python3.8/site-packages (from catboost->autoviml) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from pandas->autoviml) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from pandas->autoviml) (2021.1)
# Requirement already satisfied: pygments in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (2.8.1)
# Requirement already satisfied: pexpect>4.3 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (3.0.17)
# Requirement already satisfied: traitlets>=4.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (5.0.5)
# Requirement already satisfied: backcall in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (0.2.0)
# Requirement already satisfied: pickleshare in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (0.7.5)
# Requirement already satisfied: decorator in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (5.0.6)
# Requirement already satisfied: setuptools>=18.5 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipython->autoviml) (52.0.0.post20210125)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jedi>=0.16->ipython->autoviml) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from pexpect>4.3->ipython->autoviml) (0.7.0)
# Requirement already satisfied: wcwidth in /home/oem/Downloads/yes/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviml) (0.2.5)
# Requirement already satisfied: ipython-genutils in /home/oem/Downloads/yes/lib/python3.8/site-packages (from traitlets>=4.2->ipython->autoviml) (0.2.0)
# Requirement already satisfied: nbconvert in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jupyter->autoviml) (6.0.7)
# Requirement already satisfied: qtconsole in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jupyter->autoviml) (5.0.3)
# Requirement already satisfied: ipykernel in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jupyter->autoviml) (5.3.4)
# Requirement already satisfied: jupyter-console in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jupyter->autoviml) (6.4.0)
# Requirement already satisfied: notebook in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jupyter->autoviml) (6.3.0)
# Requirement already satisfied: ipywidgets in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jupyter->autoviml) (7.6.3)
# Requirement already satisfied: tornado>=4.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipykernel->jupyter->autoviml) (6.1)
# Requirement already satisfied: jupyter-client in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipykernel->jupyter->autoviml) (6.1.12)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviml) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviml) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviml) (5.1.3)
# Requirement already satisfied: jupyter-core in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (20.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from notebook->jupyter->autoviml) (0.9.4)
# Requirement already satisfied: prometheus-client in /home/oem/Downloads/yes/lib/python3.8/site-packages (from notebook->jupyter->autoviml) (0.10.1)
# Requirement already satisfied: argon2-cffi in /home/oem/Downloads/yes/lib/python3.8/site-packages (from notebook->jupyter->autoviml) (20.1.0)
# Requirement already satisfied: jinja2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from notebook->jupyter->autoviml) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from notebook->jupyter->autoviml) (20.0.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from notebook->jupyter->autoviml) (1.5.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->autoviml) (1.14.5)
# Requirement already satisfied: pycparser in /home/oem/Downloads/yes/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviml) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from jinja2->notebook->jupyter->autoviml) (1.1.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from matplotlib->autoviml) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from matplotlib->autoviml) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from matplotlib->autoviml) (1.3.1)
# Requirement already satisfied: jupyterlab-pygments in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (0.1.2)
# Requirement already satisfied: bleach in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (3.3.0)
# Requirement already satisfied: testpath in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (0.5.3)
# Requirement already satisfied: defusedxml in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml) (1.4.3)
# Requirement already satisfied: async-generator in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviml) (1.10)
# Requirement already satisfied: nest-asyncio in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviml) (1.5.1)
# Requirement already satisfied: webencodings in /home/oem/Downloads/yes/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->autoviml) (0.5.1)
# Requirement already satisfied: click in /home/oem/Downloads/yes/lib/python3.8/site-packages (from nltk->autoviml) (7.1.2)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from numba->shap>=0.36.0->autoviml) (0.36.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: qtpy in /home/oem/Downloads/yes/lib/python3.8/site-packages (from qtconsole->jupyter->autoviml) (1.9.0)
# Requirement already satisfied: requests in /home/oem/Downloads/yes/lib/python3.8/site-packages (from vaderSentiment->autoviml) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from requests->vaderSentiment->autoviml) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from requests->vaderSentiment->autoviml) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from requests->vaderSentiment->autoviml) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from requests->vaderSentiment->autoviml) (2.10)
# Building wheels for collected packages: shap, emoji
#   Building wheel for shap (PEP 517) ... done
#   Created wheel for shap: filename=shap-0.40.0-cp38-cp38-linux_x86_64.whl size=567373 sha256=dbcb1443a39899839ac3711bee5fcd491f79ee39f3a63322e40cd3e3264099fb
#   Stored in directory: /home/oem/.cache/pip/wheels/77/07/6b/ff54f2fdec86581ea5f6131ec0fd424bef58841d6684035114
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.6.1-py3-none-any.whl size=169294 sha256=8cf435117715ba05d65b904999f9fb8b48c4990da25b757e2c53b3a391b7d237
#   Stored in directory: /home/oem/.cache/pip/wheels/04/29/50/1e7189f03d2cf139e469863d54a1d3eabeb10c92c84e51f8a1
# Successfully built shap emoji
# Installing collected packages: packaging, tenacity, slicer, plotly, graphviz, xgboost, vaderSentiment, textblob, shap, imbalanced-learn, emoji, catboost, autoviml
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# Successfully installed autoviml-0.1.683 catboost-1.0.0 emoji-1.6.1 graphviz-0.17 imbalanced-learn-0.8.1 packaging-21.0 plotly-5.3.1 shap-0.40.0 slicer-0.0.7 tenacity-8.0.1 textblob-0.17.1 vaderSentiment-3.3.2 xgboost-1.5.0
# Requirement already satisfied: shap in /home/oem/Downloads/yes/lib/python3.8/site-packages (0.40.0)
# Requirement already satisfied: slicer==0.0.7 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (4.59.0)
# Requirement already satisfied: pandas in /home/oem/.local/lib/python3.8/site-packages (from shap) (1.3.4)
# Requirement already satisfied: numba in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (0.53.1)
# Requirement already satisfied: cloudpickle in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (1.6.0)
# Requirement already satisfied: scipy in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (1.7.1)
# Requirement already satisfied: numpy in /home/oem/.local/lib/python3.8/site-packages (from shap) (1.21.3)
# Requirement already satisfied: scikit-learn in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (0.24.1)
# Requirement already satisfied: packaging>20.9 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from shap) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from packaging>20.9->shap) (2.4.7)
# Requirement already satisfied: setuptools in /home/oem/Downloads/yes/lib/python3.8/site-packages (from numba->shap) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: pytz>=2017.3 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/oem/Downloads/yes/lib/python3.8/site-packages (from scikit-learn->shap) (2.1.0)

# %%
from autoviml.Auto_ViML import Auto_ViML
import pandas as pd
import numpy as np
# Out:
# Imported Auto_ViML version: 0.1.683. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.0.47.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>

# %%
df = pd.read_csv('knn_data.csv')

# %%
df.head()
# Out:
#                              patient_id          full_name  \
# 0  1d604da9-9a81-4ba9-80c2-de3375d59b40        Keaton Wade
# 1  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae       Branson Webb
# 2  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae        Cassie Cobb
# 3  10339b10-3cd1-4ac3-ac13-ec26728cb592      Camron Ortega
# 4  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a  Mallory Macdonald
#
#                           address  age_days  age_year  gender  height  weight  \
# 0      427 Balistreri Way Unit 19     18393     50.39       2     168   62.00
# 1        422 Farrell Path Unit 69     20228     55.42       1     156   85.00
# 2       1056 Harris Lane Suite 70     18857     51.66       1     165   64.00
# 3                  999 Kuhn Forge     17623     48.28       2     169   82.00
# 4  1050 Lindgren Extension Apt 38     17474     47.87       1     156   56.00
#
#    ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  cardio
# 0    110     80            1     1      0     0       1       0
# 1    140     90            3     1      0     0       1       1
# 2    130     70            3     1      0     0       0       1
# 3    150    100            1     1      0     0       1       1
# 4    100     60            1     1      0     0       0       0

# %%
df.shape[0]
# Out:
# 70000

# %%
70000*0.9
# Out:
# 63000.0

# %%
num = int(0.9*df.shape[0])
train = df[:num]
test = df[num:]
sample_submission=''
scoring_parameter = 'balanced-accuracy'

# %%
m, feats, trainm, testm = Auto_ViML(train, target, test, sample_submission,
                                    scoring_parameter=scoring_parameter,
                                    hyper_param='GS',feature_reduction=True,
                                     Boosting_Flag=True,Binning_Flag=False,
                                    Add_Poly=0, Stacking_Flag=False,                                    
                                    Imbalanced_Flag=False, 
                                    verbose=1)
# Out:
# ##############  D A T A   S E T  A N A L Y S I S  #######################
# ALERT! Changing hyperparameter search to RS. Otherwise XGBoost will take too long for 10,000+ rows.
# Training Set Shape = (63000, 16)
#     Training Set Memory Usage = 7.69 MB
# Test Set Shape = (7000, 16)
#     Test Set Memory Usage = 0.85 MB
# Single_Label Target: ['cardio']
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Random shuffling the data set before training
#     Using RandomizedSearchCV for Hyper Parameter Tuning. This is 3X faster than GridSearchCV...
#        Class  -> Counts -> Percent
#            0:   31543  ->   50.1%
#            1:   31457  ->   49.9%
#     Target cardio is already numeric. No transformation done.
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  4
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     15 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
#
#     No GPU active on this device
# #############     D A T A    P R E P A R A T I O N   AND C L E A N I N G     #############
# No Missing Values in train data set
#     Test data has no missing values. Continuing...
#     Completed Label Encoding and Filling of Missing Values for Train and Test Data
# Binary_Classification problem: hyperparameters are being optimized for balanced_accuracy
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package wordnet to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet31.zip.
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /home/oem/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/oem/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Auto NLP processing on NLP Column: patient_id
# Shape of Train Data: 63000 rows
#     Shape of Test Data: 7000 rows
#     Added 9 summary columns for counts of words and characters in each row
# Cleaning text in Train data for patient_id column
#     Faster text processing using clean_tweets function, since top_num_features exceeds 300
# Train data Text cleaning completed. Time taken = 62 seconds
#
# For target = cardio
#
#     For class = 0
# Top 200 n-grams
# : ['fc', 'ab', 'ec', 'eb', 'ea', 'ba', 'aa', 'cc', 'bc', 'ed', 'ef', 'df', 'db', 'ca', 'bb', 'af', 'fa', 'ad', 'bf', 'ee', 'dd', 'da', 'cb', 'dc', 'bd', 'ac', 'cd', 'ff', 'fb', 'ae', 'de', 'fd', 'ce', 'fe', 'cf', 'bfa', 'aea', 'adf', 'bac', 'bca', 'aaa', 'beb', 'fbb', 'dab', 'bbe', 'aba', 'bec', 'bbd', 'fdc', 'add', 'acf', 'fbe', 'abb', 'feb', 'bfb', 'fcc', 'edb', 'baa', 'fad', 'acc', 'cad', 'aac', 'fda', 'dea', 'cfc', 'cfb', 'fdb', 'dfb', 'dac', 'baf', 'dabd', 'dee', 'adb', 'ead', 'cce', 'ebd', 'cbe', 'cfd', 'fce', 'abc', 'ffa', 'fea', 'ecf', 'bfc', 'eac', 'dff', 'fef', 'edc', 'fca', 'ddfe', 'cae', 'dcb', 'abe', 'cab', 'eca', 'aee', 'cde', 'bdc', 'aab', 'fed', 'dcc', 'eea', 'cbf', 'efa', 'efcb', 'aca', 'dccb', 'bba', 'afb', 'aeb', 'dfa', 'dec', 'bee', 'eaf', 'ebb', 'bdf', 'cdef', 'dfeb', 'faf', 'fac', 'ada', 'adbf', 'bcf', 'dca', 'ace', 'eaa', 'bbc', 'cda', 'ddc', 'fcb', 'afe', 'cea', 'bbee', 'e b', 'c b', 'b f', 'b b', 'f b', 'b e', 'c e', 'f c', 'e c', 'c c', 'b c', 'f f', 'c f', 'f e', 'e f', 'e e', 'af b', 'c ec', 'b fc', 'fc c', 'ca b', 'f aa', 'c ad', 'bb c', 'fa e', 'b ac', 'c bc', 'c cb', 'e ed', 'f db', 'ba c', 'b eb', 'ad b', 'f c b', 'c b b', 'e c c', 'f b c', 'c b e', 'b e c', 'c b f', 'f f b', 'e c b', 'f b b', 'f b f', 'e c e', 'b f f', 'c e b', 'c e c', 'c e e', 'f f e', 'b f c', 'e e c', 'b c c', 'b b b', 'e b f', 'b b f', 'b e b', 'f e b', 'e b c', 'e e b', 'e f b', 'b b c', 'e f c', 'b c b', 'b c e', 'b f b']
#     Top n-grams that are most frequent in this class are: 199
#
#     For class = 1
# Top 200 n-grams
# : ['ec', 'ab', 'fc', 'ba', 'ea', 'bc', 'ef', 'eb', 'aa', 'df', 'db', 'ac', 'ed', 'cc', 'ca', 'cb', 'dd', 'ad', 'ff', 'bb', 'af', 'bd', 'bf', 'dc', 'de', 'fb', 'da', 'fe', 'fa', 'cd', 'ce', 'ae', 'ee', 'fd', 'cf', 'bfa', 'fbe', 'bca', 'feb', 'aaa', 'fda', 'dfb', 'aea', 'adf', 'ffa', 'edb', 'acc', 'bec', 'cfc', 'bbe', 'cfd', 'fbb', 'bfb', 'add', 'beb', 'afc', 'bac', 'fdc', 'ebd', 'abb', 'acf', 'cae', 'dff', 'cfb', 'bba', 'edc', 'dab', 'bee', 'ead', 'ace', 'aab', 'baa', 'adb', 'afb', 'bbd', 'dac', 'faf', 'ebb', 'fcc', 'aae', 'bbfe', 'aca', 'cad', 'fad', 'fca', 'cde', 'aadd', 'eac', 'fea', 'dfa', 'cab', 'ddfe', 'dabd', 'baf', 'aeb', 'eba', 'baaf', 'bdbca', 'aac', 'dea', 'fef', 'cbe', 'bfe', 'dfeb', 'fcd', 'cbc', 'bfc', 'ffc', 'aba', 'fdf', 'eaa', 'abe', 'bad', 'fbd', 'aeaf', 'bbc', 'caa', 'bdf', 'ddf', 'bdb', 'daf', 'cdb', 'fdb', 'dca', 'fcb', 'dfad', 'bedb', 'ade', 'cea', 'cdef', 'dcc', 'cff', 'eaf', 'c b', 'f b', 'e b', 'b f', 'f c', 'b e', 'c e', 'b b', 'e c', 'c c', 'c f', 'b c', 'f e', 'f f', 'e f', 'e e', 'ec b', 'ab f', 'f eb', 'af b', 'da b', 'b fc', 'b bc', 'ea b', 'aa b', 'c ec', 'b ea', 'c ad', 'f cc', 'b ab', 'b dc', 'bb c', 'eb f', 'b e c', 'f b c', 'c b b', 'b f f', 'e c c', 'f c b', 'c b e', 'f f b', 'f f e', 'e c b', 'c b f', 'c e b', 'c e f', 'f c f', 'b c b', 'f b b', 'e b c', 'c f c', 'b e b', 'e b f', 'b f b', 'e c e', 'b b f', 'b b b', 'f b e', 'b f c', 'e f b', 'c e c', 'b e e', 'e f c', 'f c c', 'b c c', 'e e c']
#     Top n-grams that are most frequent in this class are: 199
# Time Taken = 0 seconds
# ##################    THIS IS FOR BUILD_MODEL = FALSE           #################
# Building Model and Pipeline for NLP column = patient_id. This will take time...
#        Class  -> Counts -> Percent
#            0:   31543  ->   50.1%
#            1:   31457  ->   49.9%
#     Selected the maximum number of features limit = 6133
# Performing RandomizedSearchCV across 30 params. Optimizing for accuracy
#     Using train data = (50400,) and Cross Validation data = (12600,)
# Using a Calibrated Classifier in this Multi_Classification dataset to improve results...
# Since top_num_features = 300, selecting Random Forest Classifier model. If you need different model, decrease it <300.
# Training completed. Time taken for training = 155.7 minutes
# Best Params of NLP pipeline are: {'selectkbest__k': 2119, 'tfidfvectorizer__binary': True, 'tfidfvectorizer__encoding': 'utf-8', 'tfidfvectorizer__max_df': 0.3269035161412267}
# <style>.container { width:95% !important; }</style>
# <style>.container { width:95% !important; }</style>
#   Now transforming Train data to return as output...
#   Transforming Test data to return as output...
# ##################    AFTER BEST NLP TRANSFORMER SELECTED, NOW ENRICH TEXT DATA  #####################
#     Now we will start transforming NLP_column for train and test data using best vectorizer...
# Reducing dimensions from 6133 term-matrix to 100 dimensions using TruncatedSVD...
#     Reduced dimensional array shape to (63000, 100)
#     Time Taken for Truncated SVD = 12 seconds
# TruncatedSVD Data Frame size = (63000, 100)
# Reducing dimensions from 6133 term-matrix to 100 dimensions using TruncatedSVD...
#     Reduced dimensional array shape to (7000, 100)
#     Time Taken for Truncated SVD = 0 seconds
# TruncatedSVD Data Frame size = (7000, 100)
# Creating word clusters using term matrix of size: 63000 for Train data set...
#     Running k-means on NLP token matrix to create 5 word clusters.
#     Created one new column: patient_id_word_cluster_patient_id using KMeans_Clusters on NLP transformed columns...
#     Running k-means on NLP token matrix to create 5 word clusters.
#     Created word clusters using NLP transformed matrix for Test data set...
#     Time Taken for creating word cluster labels  = 26 seconds
# Since samples in data > 10000 using TextBlob, which is faster to add sentiment scores...
#     Added 4 columns using TextBlob Sentiment Analyzer. Time Taken = 147 seconds
# Number of new columns created using NLP = 128
# Time taken for Auto_NLP to complete = 160.5 minutes
# #########          A U T O   N L P  C O M P L E T E D    ###############################
# ############# R E M O V I N G   H I G H L Y  C O R R E L A T E D    V A R S #################
# Removing highly correlated variables using SULA method among (128) numeric variables
#     Removing (6) highly correlated variables:
#     ['age_year', 'patient_id_mean_word_length', 'patient_id_punctuation_count', 'patient_id_text_sentiment', 'patient_id_senti_polarity', 'patient_id_overall_sentiment']
# Splitting features into float and categorical (integer) variables:
#     (102) float variables ...
#     (20) categorical vars...
# ############## F E A T U R E   S E L E C T I O N    BY   X G B O O S T    ####################
# Current number of predictors = 122
#     Finding Important Features using Boosted Trees algorithm...
#         using 122 variables...
#         using 98 variables...
#         using 74 variables...
#         using 50 variables...
#         using 26 variables...
#         using 2 variables...
# Found 57 important features
#     Performing limited feature engineering for binning, add_poly and KMeans_Featurizer flags  ...
#     Train CV Split completed with TRAIN rows =  50400 , CV rows =  12600
#     Binning_Flag set to False or there are no float vars in data set to be binned
#     KMeans_Featurizer set to False or there are no float variables in data
# Performing MinMax scaling of train and validation data
# ############### XGBoost M O D E L   B U I L D I N G  B E G I N S  ####################
# Rows in Train data set = 50400
#   Features in Train data set = 57
#     Rows in held-out data set = 12600
# Finding Best Model and Hyper Parameters for XGBoost model...
#     Baseline Accuracy Needed for Model = 50.07%
#     CPU Count = 8 in this device
# Using XGBoost Model, Estimated Training time = 17.95 mins
#     Actual training time (in seconds): 8932
# ###########  Single_Label  M O D E L   R E S U L T S #################
# 5-fold Cross Validation  balanced-accuracy = 73.7%
#     Best Parameters for Model = {'gamma': 3, 'learning_rate': 0.04669572050695325, 'max_depth': 4, 'n_estimators': 276}
# Finding Best Threshold for Highest F1 Score...
#     Using threshold=0.5. However, 0.363 provides better F1=0.74 for rare class...
# ########################################################
# XGBoost Model Prediction Results on Held Out CV Data Set:
#     Regular Accuracy Score = 71.1%
# Balanced Accuracy = 72.87% with Threshold = 0.50
# Confusion Matrix:
# [[4905 1404]
#  [2014 4277]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      6309
#            1       0.75      0.68      0.71      6291
#
#     accuracy                           0.73     12600
#    macro avg       0.73      0.73      0.73     12600
# weighted avg       0.73      0.73      0.73     12600
#
# Balanced Accuracy = 71.12% with Threshold = 0.36
# Confusion Matrix:
# [[3806 2503]
#  [1138 5153]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.60      0.68      6309
#            1       0.67      0.82      0.74      6291
#
#     accuracy                           0.71     12600
#    macro avg       0.72      0.71      0.71     12600
# weighted avg       0.72      0.71      0.71     12600
#
# #####################################################################
# Regular threshold = 0.50 is better
# ################# E N S E M B L E  M O D E L  ##################
# Time taken = 23 seconds
# Based on trying multiple models, Best type of algorithm for this data set is Bagging_Classifier
# #############################################################################
#     Displaying results of weighted average ensemble of 5 classifiers
# <style>.container { width:95% !important; }</style>
# After multiple models, Ensemble Model Results:
# Binary Class Model Metrics Report
# #####################################################
#     Accuracy          = 71.1%
#     Balanced Accuracy = 71.1%
#     Precision         = 67.3%
#     Average Precision = 72.1%
#     Recall            = 81.9%
#     F1 Score          = 73.9%
# #####################################################
#               precision    recall  f1-score   support
#
#            0       0.77      0.60      0.68      6309
#            1       0.67      0.82      0.74      6291
#
#     accuracy                           0.71     12600
#    macro avg       0.72      0.71      0.71     12600
# weighted avg       0.72      0.71      0.71     12600
#
# [[3806 2503]
#  [1139 5152]]
# #############################################################################
# Single Model is better than Ensembling Models for this data set.
#     Time taken for this Target (in seconds) = 18987
#     Binning_Flag set to False or there are no float vars in data set to be binned
# Performing MinMax scaling of train and test data...
# #####   T R A I N I N G   M O D E L   O N    F U L L   T R A I N  D A T A  #############
#      Actual Training time taken in seconds = 217
# Training of models completed. Now starting predictions on test data...
#     Making test Data predictions using modified Threshold = 0.363
#     Calculating weighted average ensemble of 5 classifiers
#     Plotting Feature Importances to explain the output of model
# ############### P R E D I C T I O N  O N  T E S T   C O M P L E T E D  #################
#     Time taken thus far (in seconds) = 19223
# Writing Output files to disk...
#     Saving predictions to ./cardio/cardio_Binary_Classification_test_modified.csv
#     Saving predictions to ./cardio/cardio_Binary_Classification_submission.csv
#     Saving predictions to ./cardio/cardio_Binary_Classification_train_modified.csv
# ###############  C O M P L E T E D  ################
# Time Taken in mins = 320.5 for the Entire Process
